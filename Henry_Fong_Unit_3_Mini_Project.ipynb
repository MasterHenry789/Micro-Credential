# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterHenry789/Micro-Credential/blob/main/Henry_Fong_Unit_3_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - Environment Set Up
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style 
# %matplotlib inline
import seaborn as sns

# %%
# Task 2 - Data Collection
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties-2022.csv')

# %%
df.head()
# Out:
#          date   county    state    fips  cases  deaths
# 0  2022-01-01  Autauga  Alabama  1001.0  11018   160.0
# 1  2022-01-01  Baldwin  Alabama  1003.0  39911   593.0
# 2  2022-01-01  Barbour  Alabama  1005.0   3860    81.0
# 3  2022-01-01     Bibb  Alabama  1007.0   4533    95.0
# 4  2022-01-01   Blount  Alabama  1009.0  11256   198.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (690015, 6)

# %%
df.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
plt.scatter(df['state'],df['deaths'])
plt.grid()
plt.xlabel("State")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
plt.scatter(df['cases'],df['deaths'])
plt.grid()
plt.xlabel("Cases")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
df.plot(x='cases', y= 'deaths', kind = 'hist', bins=10)

# %%
# Task 3 - Data Wrangling and EDA
ny_df = df[df['state']=='New York']

# %%
ny_df.head()
# Out:
#             date       county     state     fips  cases  deaths
# 1849  2022-01-01       Albany  New York  36001.0  41708   439.0
# 1850  2022-01-01     Allegany  New York  36003.0   7005   137.0
# 1851  2022-01-01       Broome  New York  36007.0  33926   466.0
# 1852  2022-01-01  Cattaraugus  New York  36009.0  11573   189.0
# 1853  2022-01-01       Cayuga  New York  36011.0  11551   120.0

# %%
ny_df.shape
# Out:
# (12296, 6)

# %%
ny_df.tail()
# Out:
#               date       county     state     fips   cases  deaths
# 688662  2022-07-31   Washington  New York  36115.0   13857   123.0
# 688663  2022-07-31        Wayne  New York  36117.0   19474   187.0
# 688664  2022-07-31  Westchester  New York  36119.0  293034  2772.0
# 688665  2022-07-31      Wyoming  New York  36121.0    9139    85.0
# 688666  2022-07-31        Yates  New York  36123.0    3910    40.0

# %%
#first death in NY
first_ny_death = ny_df[ny_df['deaths']!=0]
first_ny_death.head()
# Out:
#             date       county     state     fips  cases  deaths
# 1849  2022-01-01       Albany  New York  36001.0  41708   439.0
# 1850  2022-01-01     Allegany  New York  36003.0   7005   137.0
# 1851  2022-01-01       Broome  New York  36007.0  33926   466.0
# 1852  2022-01-01  Cattaraugus  New York  36009.0  11573   189.0
# 1853  2022-01-01       Cayuga  New York  36011.0  11551   120.0

# %%
#total number of cases
ny_df['cases'].max()
# Out:
# 2713435

# %%
# not a correct way of calculating total count bcoz data is cumulative
ny_df['cases'].sum()
# Out:
# 1082787935

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2c828b9a10>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.plot(x='cases', y= 'deaths', kind = 'hist', bins=5)

# %%
#new cases for NY
# type(ny_df['cases'])

newcase = []
previuos_case = 0
for index, row in ny_df.iterrows():
  current_case = row['cases']
  newcase_count = current_case - previuos_case
  previuos_case = current_case
  newcase.append(newcase_count)
  # print(newcase_count)

# %%
ny_df['new_cases'] = newcase
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newcase
# Out:
# [41708,
#  -34703,
#  26921,
#  -22353,
#  -22,
#  6272,
#  -2541,
#  -8497,
#  3272,
#  -2996,
#  316,
#  -1822,
#  40909,
#  104798,
#  -147495,
#  2733,
#  2621,
#  1147,
#  -4033,
#  -5605,
#  9616,
#  3108,
#  -8559,
#  3810,
#  632,
#  106004,
#  -106772,
#  293897,
#  1292316,
#  -1559816,
#  4884,
#  32423,
#  -57871,
#  63589,
#  -71374,
#  10937,
#  -10762,
#  10568,
#  4181,
#  46800,
#  -36841,
#  -8525,
#  -19405,
#  -1033,
#  1574,
#  11285,
#  -503,
#  312245,
#  -314477,
#  -4800,
#  3950,
#  10885,
#  -13375,
#  -808,
#  4053,
#  174272,
#  -180428,
#  -3892,
#  39811,
#  -35206,
#  27273,
#  -22684,
#  10,
#  6341,
#  -2579,
#  -8547,
#  3333,
#  -3056,
#  330,
#  -1839,
#  41561,
#  105614,
#  -148947,
#  2716,
#  2614,
#  1169,
#  -4046,
#  -5651,
#  9678,
#  3124,
#  -8627,
#  3826,
#  670,
#  106923,
#  -107723,
#  299900,
#  1321926,
#  -1595116,
#  4782,
#  32923,
#  -58535,
#  64762,
#  -72615,
#  11041,
#  -10841,
#  10836,
#  4139,
#  47379,
#  -37291,
# ...

# %%
ny_df.head(10)
# Out:
#             date       county     state     fips  cases  deaths  new_cases
# 1849  2022-01-01       Albany  New York  36001.0  41708   439.0      41708
# 1850  2022-01-01     Allegany  New York  36003.0   7005   137.0     -34703
# 1851  2022-01-01       Broome  New York  36007.0  33926   466.0      26921
# 1852  2022-01-01  Cattaraugus  New York  36009.0  11573   189.0     -22353
# 1853  2022-01-01       Cayuga  New York  36011.0  11551   120.0        -22
# 1854  2022-01-01   Chautauqua  New York  36013.0  17823   223.0       6272
# 1855  2022-01-01      Chemung  New York  36015.0  15282   194.0      -2541
# 1856  2022-01-01     Chenango  New York  36017.0   6785   101.0      -8497
# 1857  2022-01-01      Clinton  New York  36019.0  10057    58.0       3272
# 1858  2022-01-01     Columbia  New York  36021.0   7061   121.0      -2996

# %%
ny_df['new_cases'].sum()
# Out:
# 3910

# %%
ny_cases = ny_df['cases']
ny_deaths = ny_df['deaths']
ny_dates = ny_df['date']
ny_new_cases = ny_df['new_cases']

# %%
type(ny_new_cases)
# Out:
# pandas.core.series.Series

# %%
ny_df.plot(kind='bar')

# %%
# load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
sns.displot(ny_df, x="deaths")

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates, height=ny_new_cases, color='red')
plt.xticks(rotation=90)
plt.show()

# %%
# Task 4 - Understand NY covid 19 data in last 30 days
ny_cases_30 = ny_df['cases'][-31:-1]
ny_deaths_30 = ny_df['deaths'] [-31:-1]
ny_dates_30 = ny_df['date'][-31:-1]
ny_new_cases_30 = ny_df['new_cases'][-31:-1]

# %%
# ny_dates_30

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_new_cases_30, color=('red'))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.bar(x=ny_dates_30, height=ny_deaths_30, color='blue')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Comparing Covid 19 data with different states

# %%
states = ['New York', 'California','Florida', 'Texas','Massachusetts']

# %%
plt.figure(figsize=(15,7))
for state in states:
  df_st = df[(df['state']==state) & (df['date']>='2021-11-01')]
  plt.plot(df_st['date'],
           df_st['cases'],
           linewidth=2
           )
  plt.xticks(rotation=90)
plt.legend(states)
plt.show()

# %% [markdown]
# # Task 6 - Conclusion
#
# Judging by the data, there is a error in the code but from what we can see is that California, Florida, Texas, Massachusetts, New York City from left to right was the highest and to the lowest in terms of Covid Cases. Due to errors in code, for counties Westchester, Albany and Broome are highest in COVID cases.
